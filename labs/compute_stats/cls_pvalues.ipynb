# %%
import numpy as np 
import pickle 

with open("../../outputs/efficient_b0/pickles/cls_p_values.pkl", 'rb') as f:
    values = pickle.load(f)

# %%
len(values)
# Out:
# 81

# %%
import matplotlib.pyplot as plt 
for v in values:
    print(v.min(), v.max())
    print(v.size())
    plt.hist(v[1])
# Out:
# tensor(0.) tensor(1.)
# torch.Size([32, 1000])
# tensor(0.) tensor(1.)
# torch.Size([32, 1000])
# tensor(0.) tensor(1.)
# torch.Size([8, 1000])
# tensor(0.) tensor(1.)
# torch.Size([32, 1000])
# tensor(0.) tensor(1.)
# torch.Size([16, 1000])
# tensor(0.) tensor(1.)
# torch.Size([96, 1000])
# tensor(0.) tensor(1.)
# torch.Size([96, 1000])
# tensor(0.) tensor(1.)
# torch.Size([4, 1000])
# tensor(0.) tensor(1.)
# torch.Size([96, 1000])
# tensor(0.) tensor(1.)
# torch.Size([24, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([6, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([24, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([6, 1000])
# tensor(0.) tensor(1.)
# torch.Size([144, 1000])
# tensor(0.) tensor(1.)
# torch.Size([40, 1000])
# ...
